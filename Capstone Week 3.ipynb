# %% [markdown]
# # Coursera Capstone Week3

# %% [markdown]
# ## Read Data

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/shayy07/Coursera_Capstone/master/TORONTONB.csv")
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ## Process Borough

# %% [markdown]
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned. <br>
# So we need to remove rows with Borough = "Not assigned"

# %%
#Read data
df_test=df.sort_values(by=['Postcode'])
df_test['Borough'].value_counts()
# Out:
# Not assigned        77
# Etobicoke           45
# North York          38
# Downtown Toronto    37
# Scarborough         37
# Central Toronto     17
# West Toronto        13
# York                 9
# East Toronto         7
# East York            6
# Mississauga          1
# Queen's Park         1
# Name: Borough, dtype: int64

# %%
df_test=df_test[df_test.Borough!="Not assigned"]
df_test['Borough'].value_counts()
# Out:
# Etobicoke           45
# North York          38
# Downtown Toronto    37
# Scarborough         37
# Central Toronto     17
# West Toronto        13
# York                 9
# East Toronto         7
# East York            6
# Mississauga          1
# Queen's Park         1
# Name: Borough, dtype: int64

# %% [markdown]
# ## Process Neighbourhood

# %% [markdown]
# Rename neighbourhood as borough when neighbourhood is "Not assigned" but borough isn't.

# %%
df_test['Neighbourhood'][(df_test['Neighbourhood'] == "Not assigned")]
df_test['Neighbourhood'][(df_test['Neighbourhood'] == "Not assigned")] = df_test['Borough']
df_test['Neighbourhood'][(df_test['Neighbourhood'] == "Not assigned")]
# Out:
# Series([], Name: Neighbourhood, dtype: object)

# %% [markdown]
# # Merge Neighbourhood with Same Postcode

# %%
df_test["NBtmp"]=df_test["Neighbourhood"]+","
df_clean = df_test.groupby(by=['Postcode','Borough'])['NBtmp'].sum().reset_index(name ='Neighbourhood')
df_clean
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...
